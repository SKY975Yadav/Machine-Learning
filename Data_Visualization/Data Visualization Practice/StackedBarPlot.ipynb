# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from seaborn import load_dataset
titanic = load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
survival_counts = titanic.groupby(['class', 'sex', 'survived']).size().unstack().fillna(0)
survival_counts
# Out:
# C:\Users\BAPS\AppData\Local\Temp\ipykernel_3836\875013270.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_counts = titanic.groupby(['class', 'sex', 'survived']).size().unstack().fillna(0)
# survived         0   1
# class  sex
# First  female    3  91
#        male     77  45
# Second female    6  70
#        male     91  17
# Third  female   72  72
#        male    300  47

# %%
survival_counts.plot(kind='bar', stacked=True, figsize=(10, 6), color=['red', 'green'])

plt.title('Survival Counts by Class and Gender')
plt.xlabel('Class and Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(['Not Survived', 'Survived'], title='Survival Status')
plt.show()
