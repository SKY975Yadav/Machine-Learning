# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load Air Passengers dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
data = pd.read_csv(url)
data = data.head(20)

# %%
data['Month'] = pd.to_datetime(data['Month'])
data
# Out:
#         Month  Passengers
# 0  1949-01-01         112
# 1  1949-02-01         118
# 2  1949-03-01         132
# 3  1949-04-01         129
# 4  1949-05-01         121
# 5  1949-06-01         135
# 6  1949-07-01         148
# 7  1949-08-01         148
# 8  1949-09-01         136
# 9  1949-10-01         119
# 10 1949-11-01         104
# 11 1949-12-01         118
# 12 1950-01-01         115
# 13 1950-02-01         126
# 14 1950-03-01         141
# 15 1950-04-01         135
# 16 1950-05-01         125
# 17 1950-06-01         149
# 18 1950-07-01         170
# 19 1950-08-01         170

# %%
data.set_index('Month', inplace=True)
data
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# 1949-06-01         135
# 1949-07-01         148
# 1949-08-01         148
# 1949-09-01         136
# 1949-10-01         119
# 1949-11-01         104
# 1949-12-01         118
# 1950-01-01         115
# 1950-02-01         126
# 1950-03-01         141
# 1950-04-01         135
# 1950-05-01         125
# 1950-06-01         149
# 1950-07-01         170
# 1950-08-01         170

# %%
plt.figure(figsize=(12, 6))
# plt.plot(data['Month'], data['Passengers'], label='Number of Passengers')
plt.plot(data, label='Number of Passengers')
plt.title('Monthly Number of Air Passengers (1949-1960)')
plt.xlabel('Date')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
