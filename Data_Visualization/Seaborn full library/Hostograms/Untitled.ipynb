# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = sns.load_dataset("penguins")
ds
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
ds.loc[(ds['flipper_length_mm'] > 229) & (ds['flipper_length_mm'] < 231)]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 253  Gentoo  Biscoe            59.6           17.0              230.0
# 285  Gentoo  Biscoe            49.8           16.8              230.0
# 295  Gentoo  Biscoe            48.6           16.0              230.0
# 309  Gentoo  Biscoe            52.1           17.0              230.0
# 333  Gentoo  Biscoe            51.5           16.3              230.0
# 335  Gentoo  Biscoe            55.1           16.0              230.0
#
#      body_mass_g   sex
# 221       5700.0  Male
# 253       6050.0  Male
# 285       5700.0  Male
# 295       5800.0  Male
# 309       5550.0  Male
# 333       5500.0  Male
# 335       5850.0  Male

# %%
sns.displot(ds['flipper_length_mm'],bins = [150,180,200,230])

# %%
sns.displot(ds['flipper_length_mm'],bins = [150,180,200,220,230,240])
plt.figure(figsize=(20, 60))  # Set width and height of the plot in inches
plt.show()

# %%
sns.displot(ds['flipper_length_mm'], bins=[150, 180, 200, 220,230,231,240], height=10, aspect=1.5)
plt.yticks(np.arange(start=0,stop=200,step=5))
plt.show()

# %%
sns.displot(ds['flipper_length_mm'],bins = [150,180,200,220,230,240],rug = True)

# %%
sns.displot(ds['flipper_length_mm'],bins = [150,180,200,220,230,240],color='r')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example dataset
df = sns.load_dataset('penguins')

# Creating a histogram
sns.histplot(data=df, x='flipper_length_mm', hue='species', bins=30, kde=True, multiple='stack')

# Display plot
plt.show()
