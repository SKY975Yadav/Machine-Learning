# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

# %%
# Define Model
model = RandomForestClassifier()

# %%
# Define Hyper parameters
hyp_parm= {
    'n_estimators': [10,15,20,26],  # Number of trees in the forest
    'max_depth': [3, 8, 10],  # Maximum depth of the tree
}

# %%
rdmCV = RandomizedSearchCV(model,hyp_parm,cv = 5)

# %%
# Load dataset
ds = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(ds.data, ds.target, test_size=0.2)

rdmCV.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [3, 8, 10],
#                                         'n_estimators': [10, 15, 20, 26]})

# %%
rdmCV.cv_results_
# Out:
# {'mean_fit_time': array([0.12707973, 0.0626349 , 0.06500225, 0.04076252, 0.0906249 ,
#         0.04578657, 0.05016661, 0.08124809, 0.07799039, 0.07817106]),
#  'std_fit_time': array([5.16946488e-02, 1.96365479e-04, 8.10018550e-03, 7.76791253e-03,
#         6.25054838e-03, 2.86738783e-03, 6.33353916e-03, 6.25047747e-03,
#         3.31310417e-03, 8.99360136e-05]),
#  'mean_score_time': array([0.00312405, 0.        , 0.003124  , 0.        , 0.00625019,
#         0.        , 0.00312471, 0.003125  , 0.        , 0.00312443]),
#  'std_score_time': array([0.00624809, 0.        , 0.006248  , 0.        , 0.00765489,
#         0.        , 0.00624943, 0.00625   , 0.        , 0.00624886]),
#  'param_n_estimators': masked_array(data=[26, 15, 15, 10, 26, 10, 15, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'param_max_depth': masked_array(data=[8, 10, 8, 10, 3, 8, 3, 10, 3, 8],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'params': [{'n_estimators': 26, 'max_depth': 8},
#   {'n_estimators': 15, 'max_depth': 10},
#   {'n_estimators': 15, 'max_depth': 8},
#   {'n_estimators': 10, 'max_depth': 10},
#   {'n_estimators': 26, 'max_depth': 3},
#   {'n_estimators': 10, 'max_depth': 8},
#   {'n_estimators': 15, 'max_depth': 3},
#   {'n_estimators': 20, 'max_depth': 10},
#   {'n_estimators': 20, 'max_depth': 3},
#   {'n_estimators': 20, 'max_depth': 8}],
#  'split0_test_score': array([0.94505495, 0.94505495, 0.94505495, 0.93406593, 0.93406593,
#         0.93406593, 0.94505495, 0.93406593, 0.92307692, 0.93406593]),
#  'split1_test_score': array([0.98901099, 0.97802198, 0.95604396, 0.97802198, 0.96703297,
#         0.97802198, 0.96703297, 0.98901099, 0.97802198, 0.98901099]),
#  'split2_test_score': array([0.92307692, 0.9010989 , 0.92307692, 0.89010989, 0.92307692,
#         0.9010989 , 0.9010989 , 0.91208791, 0.92307692, 0.91208791]),
#  'split3_test_score': array([0.93406593, 0.93406593, 0.94505495, 0.94505495, 0.92307692,
#         0.94505495, 0.94505495, 0.92307692, 0.92307692, 0.93406593]),
#  'split4_test_score': array([0.96703297, 0.95604396, 0.97802198, 0.95604396, 0.97802198,
#         0.92307692, 0.91208791, 0.95604396, 0.96703297, 0.96703297]),
#  'mean_test_score': array([0.95164835, 0.94285714, 0.94945055, 0.94065934, 0.94505495,
#         0.93626374, 0.93406593, 0.94285714, 0.94285714, 0.94725275]),
#  'std_test_score': array([0.02367105, 0.0254414 , 0.01785503, 0.02915714, 0.02305074,
#         0.0254414 , 0.02407572, 0.02727401, 0.02447369, 0.02727401]),
#  'rank_test_score': array([ 1,  5,  2,  8,  4,  9, 10,  5,  5,  3], dtype=int32)}

# %%
print("Best hyperparameters: ", rdmCV.best_params_)
print("Best score: ", rdmCV.best_score_)
# Out:
# Best hyperparameters:  {'n_estimators': 26, 'max_depth': 8}
# Best score:  0.9516483516483516

# %%
res = pd.DataFrame(rdmCV.cv_results_)
res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.127080      0.051695         0.003124        0.006248
# 1       0.062635      0.000196         0.000000        0.000000
# 2       0.065002      0.008100         0.003124        0.006248
# 3       0.040763      0.007768         0.000000        0.000000
# 4       0.090625      0.006251         0.006250        0.007655
# 5       0.045787      0.002867         0.000000        0.000000
# 6       0.050167      0.006334         0.003125        0.006249
# 7       0.081248      0.006250         0.003125        0.006250
# 8       0.077990      0.003313         0.000000        0.000000
# 9       0.078171      0.000090         0.003124        0.006249
#
#    param_n_estimators  param_max_depth                                 params  \
# 0                  26                8   {'n_estimators': 26, 'max_depth': 8}
# 1                  15               10  {'n_estimators': 15, 'max_depth': 10}
# 2                  15                8   {'n_estimators': 15, 'max_depth': 8}
# 3                  10               10  {'n_estimators': 10, 'max_depth': 10}
# 4                  26                3   {'n_estimators': 26, 'max_depth': 3}
# 5                  10                8   {'n_estimators': 10, 'max_depth': 8}
# 6                  15                3   {'n_estimators': 15, 'max_depth': 3}
# 7                  20               10  {'n_estimators': 20, 'max_depth': 10}
# 8                  20                3   {'n_estimators': 20, 'max_depth': 3}
# 9                  20                8   {'n_estimators': 20, 'max_depth': 8}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.945055           0.989011           0.923077           0.934066
# 1           0.945055           0.978022           0.901099           0.934066
# 2           0.945055           0.956044           0.923077           0.945055
# 3           0.934066           0.978022           0.890110           0.945055
# 4           0.934066           0.967033           0.923077           0.923077
# 5           0.934066           0.978022           0.901099           0.945055
# 6           0.945055           0.967033           0.901099           0.945055
# 7           0.934066           0.989011           0.912088           0.923077
# 8           0.923077           0.978022           0.923077           0.923077
# 9           0.934066           0.989011           0.912088           0.934066
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.967033         0.951648        0.023671                1
# 1           0.956044         0.942857        0.025441                5
# 2           0.978022         0.949451        0.017855                2
# 3           0.956044         0.940659        0.029157                8
# 4           0.978022         0.945055        0.023051                4
# 5           0.923077         0.936264        0.025441                9
# 6           0.912088         0.934066        0.024076               10
# 7           0.956044         0.942857        0.027274                5
# 8           0.967033         0.942857        0.024474                5
# 9           0.967033         0.947253        0.027274                3

# %%
rdmResult = res[['param_n_estimators','param_max_depth','mean_test_score']]
rdmResult
# Out:
#    param_n_estimators  param_max_depth  mean_test_score
# 0                  26                8         0.951648
# 1                  15               10         0.942857
# 2                  15                8         0.949451
# 3                  10               10         0.940659
# 4                  26                3         0.945055
# 5                  10                8         0.936264
# 6                  15                3         0.934066
# 7                  20               10         0.942857
# 8                  20                3         0.942857
# 9                  20                8         0.947253
