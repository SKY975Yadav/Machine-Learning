# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression

# Create a sample dataset
X, y = make_regression(n_samples=500, n_features=1, noise=20, random_state=42)

# Initialize the model
model = LinearRegression()

# Generate learning curves
train_sizes, train_scores, validation_scores = learning_curve(model, X, y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calculate mean and standard deviation of training and validation scores
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
validation_scores_mean = np.mean(validation_scores, axis=1)
validation_scores_std = np.std(validation_scores, axis=1)

# Plotting the learning curves
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_scores_mean, 'o-', color='r', label='Training error')
plt.plot(train_sizes, validation_scores_mean, 'o-', color='g', label='Validation error')
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color='r')
plt.fill_between(train_sizes, validation_scores_mean - validation_scores_std, validation_scores_mean + validation_scores_std, alpha=0.1, color='g')
plt.title('Learning Curves')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
np.random.seed(0)
t = 5*np.random.rand(10,1)
t
# Out:
# array([[2.74406752],
#        [3.57594683],
#        [3.01381688],
#        [2.72441591],
#        [2.118274  ],
#        [3.22947057],
#        [2.18793606],
#        [4.458865  ],
#        [4.8183138 ],
#        [1.91720759]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the random seed for reproducibility
np.random.seed(0)

# Generate and sort the random numbers
X = np.sort(5 * np.random.rand(80, 1), axis=0)

# Generate noisy sine values
y = np.sin(X) + np.random.normal(0, 0.1, X.shape)
# Plotting
plt.scatter(X, y, color='red', label='Noisy sine wave')
plt.plot(X, np.sin(X), color='blue', label='True sine wave')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Noisy Sine Wave')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate synthetic data
np.random.seed(0)
X = np.sort(5 * np.random.rand(80, 1), axis=0)
y = np.sin(X) + np.random.normal(0, 0.1, X.shape)

# Fit linear model
linear_model = LinearRegression()
linear_model.fit(X, y)

# Fit polynomial model
poly_features = PolynomialFeatures(degree=10)
X_poly = poly_features.fit_transform(X)
poly_model = LinearRegression()
poly_model.fit(X_poly, y)

# Generate predictions
X_fit = np.linspace(0, 5, 100).reshape(-1, 1)
y_linear = linear_model.predict(X_fit)
y_poly = poly_model.predict(poly_features.transform(X_fit))

# Plotting
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X_fit, y_linear, color='red', label='Linear Fit')
plt.plot(X_fit, y_poly, color='green', label='Polynomial Fit (degree=10)')
plt.title('Overfitting Illustration')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()
